# %% [markdown]
# ### Before importing you need to install pygmaps library
#
# *   List item
# *   List item

# %%
from time import sleep
import numpy as np
import pygmaps
import folium

# %%
# pip install folium

# %% [markdown]
# ### Here is the function that returns the lattitude and longitude

# %%
def geoGrab(address):
    from geopy.geocoders import Nominatim
    geolocator = Nominatim(user_agent = 'myApp')
    location = geolocator.geocode(address)
    if location is not None:
        loc = {}
        loc['latitude'] = location.latitude
        loc['longitude'] = location.longitude
        return loc
    else:
        return None

# %% [markdown]
# ### Fill out this function placeFind()

# %%
def placeFind(fileName):
    fw = open('places.txt', 'a')
    count = 0
    for line in open(fileName).readlines():
        count += 1
        # read rows and take their exact address 
        address = line.split("	")[1].strip()      
        # use geoGrab which returns a location stored in a dictionary format
        loc =  geoGrab(address)
        if loc != None:
            # write the longitude and latitude to places.txt
            lat = loc['latitude']
            long = loc['longitude']
            fw.write(f"{lat},{long}\n")
            
        else:
            # inform about error
            print(f"An error occurred in the line {count}")
        sleep(2) # the time pause needed as it takes some time to 
                 # connect through Google API and find location
    fw.close()

# %%
# placeFind("almatyPlaces.txt")

# %% [markdown]
# ### Write your own function k-means:

# %%
x = []
for line in open("places.txt").readlines():
    m = line.strip().split(',')
    x.append([float(m[0]), float(m[1])])
x = np.array(x)

# %%
def distance(c, x):
    return np.sqrt(np.square(x[0]-c[0])+ np.square(x[1]-c[1]))

# %%
def clusterPlaces(numClust):
    # left this function empty as your code will be individual
    random_init_cent = x[np.random.choice(len(x), numClust)]
    cluster = [-1]*len(x)
    for i in range(2000):
# assign index of cluster
        for j in range(len(x)):
            dist_arr = []
            for k in range(numClust):
                dist_arr.append(distance(x[j], random_init_cent[k]))
            idx = np.argmin(dist_arr)
            cluster[j] = idx
# change centeroids by mean            
        random_init_cent = []
        for j in range(numClust):
            arr = []
            for k in range(len(x)):
                if cluster[k]==j:
                    arr.append(x[k])
            random_init_cent.append(np.mean(arr, axis=0))
#             print(random_init_cent)
    return cluster

# %% [markdown]
# At the end you need to obtain html file with points on the maps

# %%
colors = {0:'blue', 1:'orange', 2:'green', 3:'pink'}

# %%
cluster = clusterPlaces(4)

# %%
my_map = folium.Map(location=[x[0][0], x[0][1]], zoom_start=12)
for i in range(len(x)):
     folium.Marker(location=[x[i][0], x[i][1]], icon=folium.Icon(color=colors[cluster[i]])).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01706b1dc334db9c89088295a4c8ab36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01706b1dc334db9c89088295a4c8ab36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_01706b1dc334db9c89088295a4c8ab36 = L.map(
#                 &quot;map_01706b1dc334db9c89088295a4c8ab36&quot;,
#                 {
#                     center: [43.2422884, 76.9465659],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8eb8f090cb04aa3f87a5994c29e2cf37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var marker_3ae1a0bfdee397be2663d2fb18a5e26d = L.marker(
#                 [43.2422884, 76.9465659],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_8397c098d35a0c2bd8abbb155def6934 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ae1a0bfdee397be2663d2fb18a5e26d.setIcon(icon_8397c098d35a0c2bd8abbb155def6934);
#
#
#             var marker_0c8e4dde2b88b0b35960ad4ae3d1f550 = L.marker(
#                 [43.250632, 76.9576559],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_4c5524e54b77855908996f64dc641ed5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0c8e4dde2b88b0b35960ad4ae3d1f550.setIcon(icon_4c5524e54b77855908996f64dc641ed5);
#
#
#             var marker_01dd51b9712e40555095441aa696b901 = L.marker(
#                 [43.2624814, 76.9527506],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_3cf24d73e86b87d0a16e50fd1d98977a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_01dd51b9712e40555095441aa696b901.setIcon(icon_3cf24d73e86b87d0a16e50fd1d98977a);
#
#
#             var marker_1fc1ac4cc4969130aad843ce5e0944d6 = L.marker(
#                 [43.23323675, 76.93925834754282],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_7f3da380b4c3b040c43684039734e1b7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1fc1ac4cc4969130aad843ce5e0944d6.setIcon(icon_7f3da380b4c3b040c43684039734e1b7);
#
#
#             var marker_196667027d78e28a10654ee0c4ec3b31 = L.marker(
#                 [43.24426484999999, 76.95735925],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_632fc7e487cf3acdf8e952ea85a7b8c0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_196667027d78e28a10654ee0c4ec3b31.setIcon(icon_632fc7e487cf3acdf8e952ea85a7b8c0);
#
#
#             var marker_9f5affba5568f95baaddbd57476f9061 = L.marker(
#                 [43.2540914, 76.9097108],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_3159269203eb935e626d8ad06075b401 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9f5affba5568f95baaddbd57476f9061.setIcon(icon_3159269203eb935e626d8ad06075b401);
#
#
#             var marker_76a27e50e7fc0f3fd2f4762eff262301 = L.marker(
#                 [43.2601222, 76.9488505],
#                 {}
#             ).addTo(map_01706b1dc334db9c89088295a4c8ab36);
#
#
#             var icon_5d6cce3da9087cbb66fa78e88562a4f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot

# %%
# my_map.save("my_map.html")
